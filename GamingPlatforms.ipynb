# %% [markdown]
# ### Open the video game sales file using pandas. Check characteristics of the dataset. What is the shape of the dataset, what are the statistics of the columns, are there any NaNs?

# %%
import pandas as pd
vgs = pd.read_csv('vgsales.csv')
raw = pd.read_csv('vgsales.csv')

# %%
vgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
vgs.shape
# Out:
# (16598, 11)

# %%
###The maximum elements are 16598 which means every single category that has a different number has a NaN. (Year, Publisher)

# %%
vgs.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %% [markdown]
# ### Clean the dataset (if you find any NaNs)

# %%
vgs = vgs.dropna()

# %%
vgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Which game has the highest global sales? What is its platform?

# %%
vgs.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %%
vgs.sort_values(['Global_Sales'], ascending = False).head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
# The game with the highest global sales is Wii Sports in the platform Wii.

# %% [markdown]
# ### Which are the platforms in the dataset?

# %%
vgs['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
### The platforms are Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA','3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC','WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16','3DO', 'GG', 'PCFX'

# %% [markdown]
# ### Which are the top ten selling games for PS4 (Global sales)? Is this the same for Europe and Japan sales combined?

# %%
sales_PS4 = vgs[vgs['Platform'] == 'PS4']

# %%
sales_PS4.info()
sales_PS4.describe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 336 entries, 33 to 16570
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          336 non-null    int64
#  1   Name          336 non-null    object
#  2   Platform      336 non-null    object
#  3   Year          336 non-null    float64
#  4   Genre         336 non-null    object
#  5   Publisher     336 non-null    object
#  6   NA_Sales      336 non-null    float64
#  7   EU_Sales      336 non-null    float64
#  8   JP_Sales      336 non-null    float64
#  9   Other_Sales   336 non-null    float64
#  10  Global_Sales  336 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 31.5+ KB
# <bound method NDFrame.describe of         Rank                                               Name Platform  \
# 33        34                          Call of Duty: Black Ops 3      PS4
# ...

# %%
sales_PS4.sort_values(['Global_Sales'], ascending = False).head(10)
# Out:
#      Rank                            Name Platform    Year         Genre  \
# 33     34       Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# 44     45              Grand Theft Auto V      PS4  2014.0        Action
# 77     78                         FIFA 16      PS4  2015.0        Sports
# 92     93    Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 93     94  Call of Duty: Advanced Warfare      PS4  2014.0       Shooter
# 109   110                       Fallout 4      PS4  2015.0  Role-Playing
# 124   125                         FIFA 15      PS4  2014.0        Sports
# 154   155                         Destiny      PS4  2014.0       Shooter
# 221   222                         FIFA 17      PS4  2016.0        Sports
# 236   237                  The Last of Us      PS4  2014.0        Action
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 33                    Activision      5.77      5.81      0.35         2.31
# ...

# %%
# Top 10 Games are Black Ops3, Grand Theft Auto V, FIFA 16, Star Waes Battlefront, Advanced Warfare, Fallout 4, FIFA 15, Destiny, FIFA 17, The Last of Us

# %%
vgs['Eu_Jp_sales'] = vgs['EU_Sales'] + vgs['JP_Sales']
vgs
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
sales_PS4.sort_values(['Global_Sales'], ascending = False).head(10)
# Out:
#      Rank                            Name Platform    Year         Genre  \
# 33     34       Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# 44     45              Grand Theft Auto V      PS4  2014.0        Action
# 77     78                         FIFA 16      PS4  2015.0        Sports
# 92     93    Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 93     94  Call of Duty: Advanced Warfare      PS4  2014.0       Shooter
# 109   110                       Fallout 4      PS4  2015.0  Role-Playing
# 124   125                         FIFA 15      PS4  2014.0        Sports
# 154   155                         Destiny      PS4  2014.0       Shooter
# 221   222                         FIFA 17      PS4  2016.0        Sports
# 236   237                  The Last of Us      PS4  2014.0        Action
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 33                    Activision      5.77      5.81      0.35         2.31
# ...

# %%
#No its not.

# %% [markdown]
# ### How many games were released for XOne in 2016? Which was the top selling in Europe?

# %%
sales_XOne = vgs[vgs['Platform'] == 'XOne']

# %%
sales_XOne['Name'].unique()
# Out:
# array(['Call of Duty: Black Ops 3', 'Call of Duty: Advanced Warfare',
#        'Grand Theft Auto V', 'Halo 5: Guardians', 'Fallout 4',
#        'Star Wars Battlefront (2015)', "Assassin's Creed: Unity",
#        'Destiny', 'FIFA 16', 'Halo: The Master Chief Collection',
#        'Gears of War: Ultimate Edition', 'Titanfall',
#        'Call of Duty: Ghosts', 'Minecraft', 'Madden NFL 16', 'NBA 2K16',
#        "Assassin's Creed IV: Black Flag", 'Forza Motorsport 5', 'FIFA 15',
#        "Tom Clancy's The Division", 'Battlefield 4', 'Forza Motorsport 6',
#        'NBA 2K15', 'Far Cry 4', 'Watch Dogs', 'Dead Rising 3', 'FIFA 17',
#        'Madden NFL 15', 'Batman: Arkham Knight', 'Forza Horizon 2',
#        'Ryse: Son of Rome', 'Mortal Kombat X',
#        'Middle-Earth: Shadow of Mordor', 'Rise of the Tomb Raider',
#        "Tom Clancy's Rainbow Six: Siege", "Assassin's Creed Syndicate",
#        'The Elder Scrolls Online', 'The Witcher 3: Wild Hunt',
# ...

# %%
sales_XOne = vgs[vgs['Platform'] == 'XOne']

# %%
sales_XOne
# Out:
#         Rank                            Name Platform    Year         Genre  \
# 101      102       Call of Duty: Black Ops 3     XOne  2015.0       Shooter
# 193      194  Call of Duty: Advanced Warfare     XOne  2014.0       Shooter
# 197      198              Grand Theft Auto V     XOne  2014.0        Action
# 260      261               Halo 5: Guardians     XOne  2015.0       Shooter
# 287      288                       Fallout 4     XOne  2015.0  Role-Playing
# ...      ...                             ...      ...     ...           ...
# 16530  16533        Sébastien Loeb Rally Evo     XOne  2016.0        Racing
# 16531  16534                   Hitman (2016)     XOne  2016.0        Action
# 16562  16565                    Mighty No. 9     XOne  2016.0      Platform
# 16569  16572              Resident Evil 4 HD     XOne  2016.0       Shooter
# 16576  16579               Rugby Challenge 3     XOne  2016.0        Sports
#
# ...

# %%
sales_XOne_2016 = sales_XOne.drop(sales_XOne[sales_XOne['Year'] != 2016].index)

# %%
sales_XOne_2016
# Out:
#         Rank                                               Name Platform  \
# 845      847                          Tom Clancy's The Division     XOne
# 1224    1226                                            FIFA 17     XOne
# 2434    2436                                    Far Cry: Primal     XOne
# 2444    2446                                          Overwatch     XOne
# 2505    2507                                      Madden NFL 17     XOne
# 2991    2993                                        Doom (2016)     XOne
# 3145    3147                                           NBA 2K17     XOne
# 3927    3929                                      Quantum Break     XOne
# 4430    4432               Plants vs. Zombies: Garden Warfare 2     XOne
# 4820    4822                                    EA Sports UFC 2     XOne
# 5015    5017                                    Forza Horizon 3     XOne
# 5268    5270                                     Dark Souls III     XOne
# ...

# %%
sales_XOne_2016.describe()
# Out:
#                Rank    Year   NA_Sales   EU_Sales   JP_Sales  Other_Sales  \
# count     54.000000    54.0  54.000000  54.000000  54.000000    54.000000
# mean   10824.962963  2016.0   0.123889   0.085741   0.000185     0.019444
# std     4976.662328     0.0   0.217085   0.193611   0.001361     0.033782
# min      847.000000  2016.0   0.000000   0.000000   0.000000     0.000000
# 25%     6347.250000  2016.0   0.010000   0.010000   0.000000     0.000000
# 50%    12193.000000  2016.0   0.030000   0.020000   0.000000     0.005000
# 75%    15020.250000  2016.0   0.145000   0.077500   0.000000     0.027500
# max    16579.000000  2016.0   1.200000   1.260000   0.010000     0.180000
#
#        Global_Sales  Eu_Jp_sales
# count     54.000000    54.000000
# mean       0.229074     0.085926
# std        0.384753     0.193718
# min        0.010000     0.000000
# 25%        0.020000     0.010000
# 50%        0.065000     0.020000
# 75%        0.270000     0.077500
# ...

# %%
# 54 games

# %%
sales_XOne_2016.sort_values(['EU_Sales'], ascending = False).head(1)
# Out:
#       Rank     Name Platform    Year   Genre        Publisher  NA_Sales  \
# 1224  1226  FIFA 17     XOne  2016.0  Sports  Electronic Arts      0.17
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales  Eu_Jp_sales
# 1224      1.26       0.0          0.1          1.53         1.26

# %% [markdown]
# ### Replace where XOne with ‘X Box One’

# %%
vgs['Platform'] = vgs['Platform'].replace('XOne','X_Box_One')

# %%
vgs['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'X_Box_One',
#        'GC', 'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# ### How many PC games have higher sales than 3 million global sales?

# %%
vgs_PC = vgs[vgs['Platform'] == 'PC']

# %%
vgs_PC
# Out:
#         Rank                            Name Platform    Year         Genre  \
# 83        84                      The Sims 3       PC  2009.0    Simulation
# 137      138               World of Warcraft       PC  2004.0  Role-Playing
# 181      182                      Diablo III       PC  2012.0  Role-Playing
# 194      195      Microsoft Flight Simulator       PC  1996.0    Simulation
# 217      218  StarCraft II: Wings of Liberty       PC  2010.0      Strategy
# ...      ...                             ...      ...     ...           ...
# 16558  16561       Pro Evolution Soccer 2008       PC  2007.0        Sports
# 16566  16569                  End of Nations       PC  2012.0      Strategy
# 16577  16580                       Damnation       PC  2009.0       Shooter
# 16585  16588                          Breach       PC  2011.0       Shooter
# 16591  16594             Myst IV: Revelation       PC  2004.0     Adventure
#
# ...

# %%
vgs_PC_3mil = vgs_PC.drop(vgs_PC[vgs_PC['Global_Sales'] > 3].index)

# %%
vgs_PC_3mil.shape
# Out:
# (926, 12)

# %%
#12 PC games

# %% [markdown]
# ### Which action game has the highest global sales?

# %%
vgs_action = vgs[vgs['Genre'] == 'Action']

# %%
vgs['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
vgs_action.sort_values(['Global_Sales'], ascending = False).head(1)
# Out:
#     Rank                Name Platform    Year   Genre             Publisher  \
# 16    17  Grand Theft Auto V      PS3  2013.0  Action  Take-Two Interactive
#
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Eu_Jp_sales
# 16      7.01      9.27      0.97         4.14          21.4        10.24

# %% [markdown]
# ### In which year the most games were released?

# %%
vgs.groupby('Year').count().sort_values(['Name'], ascending = False).head(4)
# Out:
#         Rank  Name  Platform  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Year
# 2009.0  1431  1431      1431   1431       1431      1431      1431      1431
# 2008.0  1428  1428      1428   1428       1428      1428      1428      1428
# 2010.0  1257  1257      1257   1257       1257      1257      1257      1257
# 2007.0  1201  1201      1201   1201       1201      1201      1201      1201
#
#         Other_Sales  Global_Sales  Eu_Jp_sales
# Year
# 2009.0         1431          1431         1431
# 2008.0         1428          1428         1428
# 2010.0         1257          1257         1257
# 2007.0         1201          1201         1201

# %% [markdown]
# ### Which platform had the most releases that year?

# %%
vgs_max_Year = vgs[vgs['Year'] == 2009]

# %%
vgs_max_Year.groupby('Platform').count().sort_values(['Name'], ascending = False)
# Out:
#           Rank  Name  Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# DS         405   405   405    405        405       405       405       405
# Wii        325   325   325    325        325       325       325       325
# X360       173   173   173    173        173       173       173       173
# PS3        162   162   162    162        162       162       162       162
# PSP        161   161   161    161        161       161       161       161
# PC         109   109   109    109        109       109       109       109
# PS2         96    96    96     96         96        96        96        96
#
#           Other_Sales  Global_Sales  Eu_Jp_sales
# Platform
# DS                405           405          405
# Wii               325           325          325
# X360              173           173          173
# PS3               162           162          162
# PSP               161           161          161
# PC                109           109          109
# ...

# %% [markdown]
# ### Which are the top 5 selling platforms (games global sales) of all time? Plot your results in a graph

# %%
vgs.groupby('Platform').sum().sort_values(['Global_Sales'], ascending = False).head(5)
# Out:
#               Rank       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Platform
# PS2       15917620  4263750.0    572.92    332.63    137.54       190.47
# X360       8192936  2480191.0    594.33    278.00     12.30        84.67
# PS3        8823478  2622109.0    388.90    340.47     79.21       140.81
# Wii        9929663  2591562.0    497.37    264.35     68.28        79.20
# DS        20460770  4279469.0    388.53    194.05    175.02        60.29
#
#           Global_Sales  Eu_Jp_sales
# Platform
# PS2            1233.46       470.17
# X360            969.60       290.30
# PS3             949.35       419.68
# Wii             909.81       332.63
# DS              818.91       369.07

# %%
top_5 = vgs.groupby('Platform').sum().sort_values(['Global_Sales'], ascending = False).head(5)

# %%
top_5.groupby('Platform').sum()['Global_Sales'].plot.bar()

# %% [markdown]
# ### Which are the top three publishers in EU game sales? Use a pie plot to show their contribution. How is it compared with their global sales? Use plots to show your results.

# %%
vgs.groupby('Publisher').sum().sort_values(['EU_Sales'], ascending = False).head(3)
# Out:
#                     Rank       Year  NA_Sales  EU_Sales  JP_Sales  \
# Publisher
# Nintendo         2646098  1394666.0    815.75    418.30    454.99
# Electronic Arts  7102442  2686562.0    584.22    367.38     13.98
# Activision       6324706  1938979.0    426.01    213.72      6.54
#
#                  Other_Sales  Global_Sales  Eu_Jp_sales
# Publisher
# Nintendo               95.19       1784.43       873.29
# Electronic Arts       127.63       1093.39       381.36
# Activision             74.79        721.41       220.26

# %%
vgs_publ3 = vgs.groupby('Publisher').sum().sort_values(['EU_Sales'], ascending = False).head(3)

# %%
vgs_publ3.groupby('Publisher').sum()['EU_Sales'].plot.pie()

# %%
vgs_puball = vgs.groupby('Publisher').sum().sort_values(['Global_Sales'], ascending = False).head(10)

# %%
vgs_puball.groupby('Publisher').sum()['Global_Sales'].plot.pie()

# %%
vgs_puball.groupby('Publisher').sum()['Global_Sales'].plot.bar()

# %%
vgs_publ3
# Out:
#                     Rank       Year  NA_Sales  EU_Sales  JP_Sales  \
# Publisher
# Nintendo         2646098  1394666.0    815.75    418.30    454.99
# Electronic Arts  7102442  2686562.0    584.22    367.38     13.98
# Activision       6324706  1938979.0    426.01    213.72      6.54
#
#                  Other_Sales  Global_Sales  Eu_Jp_sales
# Publisher
# Nintendo               95.19       1784.43       873.29
# Electronic Arts       127.63       1093.39       381.36
# Activision             74.79        721.41       220.26

# %%
vgs_publ3.plot.bar(y = ['EU_Sales', 'Global_Sales'], rot = 40)

# %% [markdown]
# ### Which are the top 5 most mentioned genres of all time? Is this different in 2014, 2015, 2016?

# %%
vgs.groupby('Genre').sum().sort_values(['Global_Sales'], ascending = False).head(5)
# Out:
#                   Rank       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action        25955792  6527703.0    861.77    516.48    158.65       184.92
# Sports        17105195  4620621.0    670.09    371.34    134.76       132.65
# Shooter        9399409  2571588.0    575.16    310.45     38.18       101.90
# Role-Playing  11840252  2950365.0    326.50    187.57    350.29        59.38
# Platform       6019939  1753335.0    445.99    200.65    130.65        51.51
#
#               Global_Sales  Eu_Jp_sales
# Genre
# Action             1722.84       675.13
# Sports             1309.24       506.10
# Shooter            1026.20       348.63
# Role-Playing        923.83       537.86
# Platform            829.13       331.30

# %%
genre_2016 = vgs[vgs['Year'] == 2016]

# %%
genre_2016.groupby('Genre').sum().sort_values(['Global_Sales'], ascending = False).head(5)
# Out:
#                  Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action        1364464  237888.0      5.87      6.36      5.78         1.83
# Shooter        279947   64512.0      7.44      7.70      0.61         2.42
# Sports         360626   76608.0      4.57      7.36      0.78         1.92
# Role-Playing   425798   80640.0      1.39      1.29      3.63         0.44
# Fighting       137050   28224.0      1.60      1.15      0.64         0.46
#
#               Global_Sales  Eu_Jp_sales
# Genre
# Action               19.90        12.14
# Shooter              18.22         8.31
# Sports               14.60         8.14
# Role-Playing          6.76         4.92
# Fighting              3.86         1.79

# %%
genre_2015 = vgs[vgs['Year'] == 2015]

# %%
genre_2015.groupby('Genre').sum().sort_values(['Global_Sales'], ascending = False).head(5)
# Out:
#                  Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action        2706253  513825.0     22.83     24.65     15.85         7.33
# Shooter        125348   68510.0     30.79     24.23      2.69         8.41
# Sports         529044  124930.0     18.46     16.69      0.72         5.62
# Role-Playing   706714  157170.0     13.35     12.52      6.71         3.85
# Misc           348067   78585.0      4.81      3.71      2.10         1.04
#
#               Global_Sales  Eu_Jp_sales
# Genre
# Action               70.70        40.50
# Shooter              66.15        26.92
# Sports               41.54        17.41
# Role-Playing         36.44        19.23
# Misc                 11.69         5.81

# %%
genre_2014 = vgs[vgs['Year'] == 2014]

# %%
genre_2014.groupby('Genre').sum().sort_values(['Global_Sales'], ascending = False).head(5)
# Out:
#                  Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action        1456173  374604.0     38.73     40.48      6.50        13.30
# Shooter        196375   94658.0     30.72     25.81      1.08         8.38
# Sports         320026  110770.0     19.82     18.70      1.60         6.52
# Role-Playing   792502  181260.0     13.56     11.23     17.71         3.38
# Misc           354761   82574.0      9.43      8.87      2.36         3.07
#
#               Global_Sales  Eu_Jp_sales
# Genre
# Action               99.02        46.98
# Shooter              66.00        26.89
# Sports               46.66        20.30
# Role-Playing         45.85        28.94
# Misc                 23.68        11.23

# %%
# 2014: Action, Shooter, Sports, Role Playing, Misc
# 2015: Action, Shooter, Sports, Role Playing, Misc
# 2016: Action, Shooter, Sports, Role Playing, Fighting
#Of All Times:  Action, Shooter, Sports, Role Playing, Platform

# %%
vgs.groupby('Year').sum().sort_values(['Global_Sales'], ascending = False).head(50)
# Out:
#             Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# Year
# 2008.0  12088007    351.44    184.40     60.26        82.39        678.90
# 2009.0  12420219    338.85    191.59     61.89        74.77        667.30
# 2007.0  10342945    311.18    160.18     60.29        77.58        609.92
# 2010.0  11034785    304.24    176.57     59.49        59.90        600.29
# 2006.0   9563593    263.12    129.24     73.73        54.43        521.04
# 2011.0   9977031    241.00    167.31     53.04        54.39        515.80
# 2005.0   7680275    241.58    121.56     54.28        40.55        458.51
# 2004.0   5677266    218.80    105.92     41.65        47.24        414.01
# 2002.0   6830188    216.19    109.74     41.76        27.28        395.52
# 2013.0   4398356    154.77    125.80     47.59        39.82        368.11
# 2012.0   5525585    154.93    118.76     51.74        37.82        363.49
# 2003.0   6110995    193.59    103.81     34.20        26.01        357.85
# ...

# %%
vgs['Year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000., 1995., 2016., 1991., 1981., 1987., 1980.,
#        1983., 2020., 2017.])

# %%
vgs_2010_2020 = vgs[vgs['Year'] >= 2010]

# %%
vgs_2010_2020.describe()
# Out:
#                Rank         Year     NA_Sales     EU_Sales     JP_Sales  \
# count   5134.000000  5134.000000  5134.000000  5134.000000  5134.000000
# mean    8903.949357  2012.251071     0.216724     0.163331     0.058192
# std     4914.303885     1.966175     0.615722     0.465067     0.227404
# min       16.000000  2010.000000     0.000000     0.000000     0.000000
# 25%     4680.250000  2011.000000     0.000000     0.000000     0.000000
# 50%     9246.000000  2012.000000     0.050000     0.030000     0.000000
# 75%    13335.500000  2014.000000     0.180000     0.130000     0.040000
# max    16599.000000  2020.000000    14.970000     9.270000     5.650000
#
#        Other_Sales  Global_Sales  Eu_Jp_sales
# count  5134.000000   5134.000000  5134.000000
# mean      0.052538      0.490923     0.221523
# std       0.155971      1.242906     0.571773
# min       0.000000      0.010000     0.000000
# 25%       0.000000      0.050000     0.020000
# ...

# %%
vgs_2010 = vgs_2010_2020.groupby('Publisher').sum().sort_values(['Global_Sales'], ascending = False).head(10)

# %%
vgs_2010.groupby('Publisher').sum()['Global_Sales'].plot.bar()
